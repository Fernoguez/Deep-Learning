# %%
import torchvision
import torchvision.transforms as transforms

# Ruta donde quieres descargar CIFAR-10
ruta_datos = "C:\\Users\\brend\\OneDrive\\Escritorio\\Documentos\\Doctorado\\Proyecto\\Datos"

# Transformación: convertir a tensor
transform = transforms.ToTensor()

# Descarga de entrenamiento y prueba
trainset = torchvision.datasets.CIFAR10(root=ruta_datos, train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root=ruta_datos, train=False, download=True, transform=transform)

print("Descarga completada en:", ruta_datos)
# Out:
# c:\Users\brend\anaconda3\envs\proyecto\Lib\site-packages\torch\_subclasses\functional_tensor.py:295: UserWarning: Failed to initialize NumPy: DLL load failed while importing _multiarray_umath: No se puede encontrar el módulo especificado. (Triggered internally at C:\b\abs_dd5ga5p9x7\croot\libtorch_1746637520098\work\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# ...
# 100.0%
# Extracting C:\Users\brend\OneDrive\Escritorio\Documentos\Doctorado\Proyecto\Datos\cifar-10-python.tar.gz to C:\Users\brend\OneDrive\Escritorio\Documentos\Doctorado\Proyecto\Datos
# Files already downloaded and verified
# Descarga completada en: C:\Users\brend\OneDrive\Escritorio\Documentos\Doctorado\Proyecto\Datos
